# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate
import warnings
import time
import sys, os
from sklearn.model_selection import KFold
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import train_test_split
from skopt import BayesSearchCV
import keras_tuner as kt
from keras.models import Sequential
from keras.layers import Dense, Input, Normalization
from tensorflow.keras.optimizers import get as get_optimizer
from sklearn.preprocessing import StandardScaler


path = 'datasets/Dataset_2.xlsx'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Read and load dataset
df= pd.read_excel(path, sheet_name="preproc")
# Out:
# Num GPUs Available:  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 24
#      22 print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#      23 # Read and load dataset
# ---> 24 df= pd.read_excel(path, sheet_name="preproc")
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/pandas/io/excel/_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/pandas/io/excel/_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/pandas/io/excel/_base.py:778, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     775     sheet = self.get_sheet_by_index(asheetname)
#     777 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 778 data = self.get_sheet_data(sheet, file_rows_needed)
#     779 if hasattr(sheet, "close"):
#     780     # pyxlsb opens two TemporaryFiles
#     781     sheet.close()
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:615, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     613 data: list[list[Scalar]] = []
#     614 last_row_with_data = -1
# --> 615 for row_number, row in enumerate(sheet.rows):
#     616     converted_row = [self._convert_cell(cell) for cell in row]
#     617     while converted_row and converted_row[-1] == "":
#     618         # trim trailing empty elements
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:85, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 with self._get_source() as src:
#      78     parser = WorkSheetParser(src,
#      79                              self._shared_strings,
#      80                              data_only=self.parent.data_only,
#      81                              epoch=self.parent.epoch,
#      82                              date_formats=self.parent._date_formats,
#      83                              timedelta_formats=self.parent._timedelta_formats)
# ---> 85     for idx, row in parser.parse():
#      86         if max_row is not None and idx > max_row:
#      87             break
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:167, in WorkSheetParser.parse(self)
#     165     element.clear()
#     166 elif tag_name == ROW_TAG:
# --> 167     row = self.parse_row(element)
#     168     element.clear()
#     169     yield row
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:303, in WorkSheetParser.parse_row(self, row)
#     299 if keys - {'r', 'spans'}:
#     300     # don't create dimension objects unless they have relevant information
#     301     self.row_dimensions[str(self.row_counter)] = attrs
# --> 303 cells = [self.parse_cell(el) for el in row]
#     304 return self.row_counter, cells
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:202, in WorkSheetParser.parse_cell(self, element)
#     199     value = element.findtext(VALUE_TAG, None) or None
#     201 if coordinate:
# --> 202     row, column = coordinate_to_tuple(coordinate)
#     203     self.col_counter = column
#     204 else:
#
# File ~/Desktop/Demetra/venv_tf/lib/python3.12/site-packages/openpyxl/utils/cell.py:215, in coordinate_to_tuple(coordinate)
#     213 col = coordinate[:idx]
#     214 row = coordinate[idx:]
# --> 215 return int(row), column_index_from_string(col)
#
# KeyboardInterrupt:

# %% [markdown]
# INPUT DATA

# %%
X = (df.iloc[:,14:]).values
print(X.shape)
# Out:
# (2905, 530)

# %% [markdown]
# OUTPUT DATA

# %%
Y = (df.iloc[:,7]).values
print(Y.shape)
# Out:
# (2905,)

# %% [markdown]
# **NRMSEPiqr**

# %%
def NRMSEPiqr(observed_values, predicted_values):
    # Calculate RMSEP
    rmsep = np.sqrt(np.mean((observed_values - predicted_values) ** 2))
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = np.percentile(observed_values, 25)
    Q3 = np.percentile(observed_values, 75)

    # Calculate IQR
    IQR = Q3 - Q1

    return rmsep/IQR

NRMSEPiqrscorer = make_scorer(NRMSEPiqr,greater_is_better=False)

# %%
X[0].shape
# Out:
# (530,)

# %% [markdown]
# Bayseian Optimization

# %%
def model_builder(hp):
  
  max_n_layer = 8
  neurons = []
  for i in range(max_n_layer):
    neurons.append(hp.Int(f"n_neurons_{i}", min_value=32, max_value=512, sampling="log"))
  hp_hidden = hp.Int('n_hidden', min_value=1, max_value=8)
  hp_learning_rate = hp.Float('learning_rate',min_value=1e-5, max_value=0.1, sampling="log")
  hp_optimizers = hp.Choice('optimizer', values = ["SGD","RMSprop","Adam"])
  optimizer = get_optimizer(hp_optimizers)
  optimizer.learning_rate = hp_learning_rate

  model = Sequential()
  model.add(Input(shape=X[0].shape))
  for k in range(hp_hidden):
    model.add(keras.layers.Dense(units=neurons[k], activation="relu"))

  model.add(keras.layers.Dense(1))


  model.compile(optimizer=hp_optimizers,
                loss="mean_absolute_error",
                metrics=["MeanSquaredError"])

  return model

# %% [markdown]
# Create Tuner

# %%
import tempfile
temp_dir = tempfile.TemporaryDirectory()

tuner = kt.BayesianOptimization(model_builder,
                     objective=kt.Objective("val_loss", direction="min"),
                     seed = 777,
                      max_trials = 100, 
                      overwrite=True,
                      directory=temp_dir.name
)

# %% [markdown]
# Start Search

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=777)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

tuner.search(X_train, Y_train, epochs=9999, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(best_hps)
# Out:
# Trial 100 Complete [00h 00m 10s]
# val_loss: 0.32751718163490295
#
# Best val_loss So Far: 0.31888633966445923
# Total elapsed time: 00h 15m 22s
# <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x77883fb9a420>

# %% [markdown]
# Evaluate best model

# %%
best_model = tuner.hypermodel.build(best_hps)
best_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 81)             │        43,011 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 133)            │        10,906 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 58)             │         7,772 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 87)             │         5,133 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 360)            │        11,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │           361 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 83,991 (328.09 KB)
#  Trainable params: 83,991 (328.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
trials = 100
random_cv = np.random.seed(777)
#Create seed list
seeds = np.random.choice(trials + 1, size=trials, replace= False)

NRMSE = np.zeros((trials), dtype="float")
MSE = np.zeros((trials), dtype="float")
RMSE = np.zeros((trials), dtype="float")

for i in range(trials):
    optimizer = get_optimizer(best_hps.get('optimizer'))
    optimizer.learning_rate = best_hps.get('learning_rate')
    best_model.compile(optimizer=optimizer, loss="mean_absolute_error",
                metrics=["MeanSquaredError"])

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=seeds[i])

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)


    best_model.fit(X_train, Y_train, epochs=9999, validation_split=0.2, callbacks=[stop_early])

    # Make predictions using the testing set
    Y_pred_mlp = best_model.predict(X_test)

    #Compute error
    NRMSE[i] = NRMSEPiqr(Y_test, Y_pred_mlp)
    MSE[i] = mean_squared_error(Y_test, Y_pred_mlp)
    RMSE[i] = tf.sqrt(mean_squared_error(Y_test, Y_pred_mlp))

mean_NRMSEP_mlp = np.mean(NRMSE)
std_nrmsep = np.std(NRMSE)
mean_MSE_mlp = np.mean(MSE)
std_mse = np.std(MSE)
mean_RMSE_mlp = np.mean(RMSE)
std_rmse = np.std(RMSE)
print("Mean NRMSEPiqr: " + str(mean_NRMSEP_mlp))
print("NRMSEPiqr Standard Deviation: " + str(std_nrmsep))
print("Mean MSE: " + str(mean_MSE_mlp))
print("MSE Standard Deviation: " + str(std_mse))
print("Mean RMSE: " + str(mean_RMSE_mlp))
print("RMSE Standard Deviation: " + str(std_rmse))
# Out:
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0294 - loss: 0.1181 - val_MeanSquaredError: 0.0275 - val_loss: 0.1129
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0206 - loss: 0.0928 - val_MeanSquaredError: 0.0242 - val_loss: 0.1036
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0188 - loss: 0.0902 - val_MeanSquaredError: 0.0293 - val_loss: 0.1111
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0228 - loss: 0.0974 - val_MeanSquaredError: 0.0250 - val_loss: 0.1102
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0194 - loss: 0.0900 - val_MeanSquaredError: 0.0359 - val_loss: 0.1192
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0222 - loss: 0.0957 - val_MeanSquaredError: 0.0324 - val_loss: 0.1177
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0164 - loss: 0.0818 - val_MeanSquaredError: 0.0267 - val_loss: 0.1051
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0181 - loss: 0.0806 - val_MeanSquaredError: 0.0239 - val_loss: 0.1034
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0151 - loss: 0.0769 - val_MeanSquaredError: 0.0259 - val_loss: 0.1062
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0159 - loss: 0.0802 - val_MeanSquaredError: 0.0341 - val_loss: 0.1190
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0181 - loss: 0.0836 - val_MeanSquaredError: 0.0288 - val_loss: 0.1147
# Epoch 12/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0191 - loss: 0.0867 - val_MeanSquaredError: 0.0309 - val_loss: 0.1170
# Epoch 13/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0220 - loss: 0.0901 - val_MeanSquaredError: 0.0336 - val_loss: 0.1201
# Epoch 14/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0165 - loss: 0.0803 - val_MeanSquaredError: 0.0630 - val_loss: 0.1670
# Epoch 15/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0428 - loss: 0.1308 - val_MeanSquaredError: 0.0395 - val_loss: 0.1341
# Epoch 16/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0241 - loss: 0.0980 - val_MeanSquaredError: 0.0340 - val_loss: 0.1256
# Epoch 17/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0207 - loss: 0.0951 - val_MeanSquaredError: 0.0353 - val_loss: 0.1259
# Epoch 18/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0268 - loss: 0.1047 - val_MeanSquaredError: 0.0281 - val_loss: 0.1131
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0290 - loss: 0.1126 - val_MeanSquaredError: 0.0406 - val_loss: 0.1363
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0315 - loss: 0.1126 - val_MeanSquaredError: 0.0306 - val_loss: 0.1183
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0227 - loss: 0.0954 - val_MeanSquaredError: 0.0281 - val_loss: 0.1131
# Epoch 4/9999
# ...
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0122 - loss: 0.0665 - val_MeanSquaredError: 0.0252 - val_loss: 0.0973
# Epoch 18/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0142 - loss: 0.0680 - val_MeanSquaredError: 0.0209 - val_loss: 0.0923
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0153 - loss: 0.0812 - val_MeanSquaredError: 0.0165 - val_loss: 0.0786
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0114 - loss: 0.0688 - val_MeanSquaredError: 0.0172 - val_loss: 0.0800
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0120 - loss: 0.0674 - val_MeanSquaredError: 0.0178 - val_loss: 0.0813
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0141 - loss: 0.0713 - val_MeanSquaredError: 0.0200 - val_loss: 0.0893
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0130 - loss: 0.0676 - val_MeanSquaredError: 0.0172 - val_loss: 0.0789
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0119 - loss: 0.0709 - val_MeanSquaredError: 0.0176 - val_loss: 0.0876
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0157 - loss: 0.0816 - val_MeanSquaredError: 0.0218 - val_loss: 0.0921
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0146 - loss: 0.0732 - val_MeanSquaredError: 0.0291 - val_loss: 0.1020
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0183 - loss: 0.0807 - val_MeanSquaredError: 0.0233 - val_loss: 0.0941
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0158 - loss: 0.0787 - val_MeanSquaredError: 0.0225 - val_loss: 0.0927
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0134 - loss: 0.0714 - val_MeanSquaredError: 0.0244 - val_loss: 0.1004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.
9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0105 - loss: 0.0632 - val_MeanSquaredError: 0.0262 - val_loss: 0.1102
# Epoch 21/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0220 - loss: 0.0876 - val_MeanSquaredError: 0.0156 - val_loss: 0.0837
# Epoch 22/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0081 - loss: 0.0586 - val_MeanSquaredError: 0.0168 - val_loss: 0.0857
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - MeanSquaredError: 0.0162 - loss: 0.0793 - val_MeanSquaredError: 0.0160 - val_loss: 0.0771
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0125 - loss: 0.0721 - val_MeanSquaredError: 0.0210 - val_loss: 0.0967
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0164 - loss: 0.0834 - val_MeanSquaredError: 0.0138 - val_loss: 0.0753
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0136 - loss: 0.0733 - val_MeanSquaredError: 0.0161 - val_loss: 0.0761
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0149 - loss: 0.0719 - val_MeanSquaredError: 0.0177 - val_loss: 0.0825
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0115 - loss: 0.0686 - val_MeanSquaredError: 0.0133 - val_loss: 0.0709
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0099 - loss: 0.0639 - val_MeanSquaredError: 0.0150 - val_loss: 0.0777
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0087 - loss: 0.0591 - val_MeanSquaredError: 0.0135 - val_loss: 0.0696
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0078 - loss: 0.0559 - val_MeanSquaredError: 0.0144 - val_loss: 0.0755
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0144 - loss: 0.0664 - val_MeanSquaredError: 0.0136 - val_loss: 0.0725
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0087 - loss: 0.0554 - val_MeanSquaredError: 0.0147 - val_loss: 0.0740
# Epoch 12/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0083 - loss: 0.0590 - val_MeanSquaredError: 0.0162 - val_loss: 0.0782
# Epoch 13/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0104 - loss: 0.0636 - val_MeanSquaredError: 0.0168 - val_loss: 0.0821
# Epoch 14/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0102 - loss: 0.0636 - val_MeanSquaredError: 0.0157 - val_loss: 0.0792
# Epoch 15/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0162 - loss: 0.0785 - val_MeanSquaredError: 0.0193 - val_loss: 0.0922
# Epoch 16/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0137 - loss: 0.0733 - val_MeanSquaredError: 0.0195 - val_loss: 0.0870
# Epoch 17/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0116 - loss: 0.0654 - val_MeanSquaredError: 0.0183 - val_loss: 0.0841
# Epoch 18/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0131 - loss: 0.0683 - val_MeanSquaredError: 0.0154 - val_loss: 0.0776
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0171 - loss: 0.0826 - val_MeanSquaredError: 0.0178 - val_loss: 0.0867
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0180 - loss: 0.0838 - val_MeanSquaredError: 0.0220 - val_loss: 0.0924
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0151 - loss: 0.0794 - val_MeanSquaredError: 0.0195 - val_loss: 0.0832
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0102 - loss: 0.0616 - val_MeanSquaredError: 0.0135 - val_loss: 0.0699
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0117 - loss: 0.0654 - val_MeanSquaredError: 0.0163 - val_loss: 0.0777
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0111 - loss: 0.0641 - val_MeanSquaredError: 0.0147 - val_loss: 0.0770
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0098 - loss: 0.0628 - val_MeanSquaredError: 0.0176 - val_loss: 0.0852
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0126 - loss: 0.0694 - val_MeanSquaredError: 0.0149 - val_loss: 0.0789
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0092 - loss: 0.0596 - val_MeanSquaredError: 0.0151 - val_loss: 0.0768
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0089 - loss: 0.0588 - val_MeanSquaredError: 0.0164 - val_loss: 0.0797
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0126 - loss: 0.0660 - val_MeanSquaredError: 0.0274 - val_loss: 0.1033
# Epoch 12/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0183 - loss: 0.0838 - val_MeanSquaredError: 0.0209 - val_loss: 0.0888
# Epoch 13/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0148 - loss: 0.0760 - val_MeanSquaredError: 0.0200 - val_loss: 0.0921
# Epoch 14/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0123 - loss: 0.0686 - val_MeanSquaredError: 0.0170 - val_loss: 0.0822
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0180 - loss: 0.0862 - val_MeanSquaredError: 0.0187 - val_loss: 0.0796
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0147 - loss: 0.0766 - val_MeanSquaredError: 0.0176 - val_loss: 0.0788
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0225 - loss: 0.0866 - val_MeanSquaredError: 0.0167 - val_loss: 0.0770
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0159 - loss: 0.0743 - val_MeanSquaredError: 0.0171 - val_loss: 0.0854
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0137 - loss: 0.0716 - val_MeanSquaredError: 0.0195 - val_loss: 0.0850
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0157 - loss: 0.0739 - val_MeanSquaredError: 0.0269 - val_loss: 0.1042
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0214 - loss: 0.0923 - val_MeanSquaredError: 0.0188 - val_loss: 0.0873
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0175 - loss: 0.0813 - val_MeanSquaredError: 0.0232 - val_loss: 0.0946
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0157 - loss: 0.0770 - val_MeanSquaredError: 0.0152 - val_loss: 0.0780
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0142 - loss: 0.0704 - val_MeanSquaredError: 0.0197 - val_loss: 0.0803
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0124 - loss: 0.0693 - val_MeanSquaredError: 0.0191 - val_loss: 0.0843
# Epoch 12/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0129 - loss: 0.0683 - val_MeanSquaredError: 0.0168 - val_loss: 0.0802
# Epoch 13/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0110 - loss: 0.0626 - val_MeanSquaredError: 0.0174 - val_loss: 0.0827
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - MeanSquaredError: 0.0170 - loss: 0.0830 - val_MeanSquaredError: 0.0149 - val_loss: 0.0787
# Epoch 2/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0136 - loss: 0.0737 - val_MeanSquaredError: 0.0166 - val_loss: 0.0814
# Epoch 3/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0162 - loss: 0.0753 - val_MeanSquaredError: 0.0145 - val_loss: 0.0740
# Epoch 4/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0117 - loss: 0.0666 - val_MeanSquaredError: 0.0139 - val_loss: 0.0766
# Epoch 5/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0113 - loss: 0.0658 - val_MeanSquaredError: 0.0131 - val_loss: 0.0741
# Epoch 6/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0110 - loss: 0.0662 - val_MeanSquaredError: 0.0131 - val_loss: 0.0745
# Epoch 7/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0123 - loss: 0.0664 - val_MeanSquaredError: 0.0156 - val_loss: 0.0745
# Epoch 8/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0132 - loss: 0.0706 - val_MeanSquaredError: 0.0183 - val_loss: 0.0888
# Epoch 9/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0171 - loss: 0.0855 - val_MeanSquaredError: 0.0149 - val_loss: 0.0791
# Epoch 10/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0111 - loss: 0.0646 - val_MeanSquaredError: 0.0175 - val_loss: 0.0828
# Epoch 11/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MeanSquaredError: 0.0118 - loss: 0.0680 - val_MeanSquaredError: 0.0139 - val_loss: 0.0751
# Epoch 12/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0105 - loss: 0.0636 - val_MeanSquaredError: 0.0164 - val_loss: 0.0830
# Epoch 13/9999
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - MeanSquaredError: 0.0126 - loss: 0.0702 - val_MeanSquaredError: 0.0163 - val_loss: 0.0820
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean NRMSEPiqr: 1.2815566438600632
# NRMSEPiqr Standard Deviation: 0.06274215537276598
# Mean MSE: 0.02672414095201431
# MSE Standard Deviation: 0.0073371608117469
# Mean RMSE: 0.1620022453715659
# RMSE Standard Deviation: 0.021895512019253324
