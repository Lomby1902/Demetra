# %%
import numpy as np
import matplotlib.pyplot as plt

def normalize(list):
    return [[elem/sum(list[0]) for elem in list[0]]]



linear_svd_mse_1 = [[2.31376, 3.30903, 3.75571, 4.9679, 6.50134, 7.1128, 9.16469, 11.892, 23.6388, 90.9341]]
linear_svd_var_1 = [[3.05192, 2.03417, 2.74071, 2.68535, 2.96322, 5.03345, 10.0503, 25.9907, 149.677, 2.10096e+27]]

linear_svd_mse_2 = [[2.47491,4.18569, 4.52331, 5.35889, 6.16109, 7.04787, 8.89899, 14.4031,  32.4691, 106.447]]
linear_svd_var_2 = [[3.88951, 2.4292, 2.26154, 2.36441, 2.69741, 4.48747, 12.0198,  28.2169, 277.319, 1.49671e+23]]

linear_sgd_mse_1 = [[1.11956, 1.39171, 1.49083, 1.6998, 1.72309, 1.82218, 1.86705, 1.91341, 1.89353, 1.95141]]
linear_sgd_var_1 = [[0.262929, 0.140912, 0.107856, 0.0688042, 0.0550604, 0.0410999, 0.0423277, 0.0299918, 0.0267675, 0.0214507]]

linear_sgd_mse_2 = [[1.11956, 1.39171, 1.49083, 1.6998, 1.72309, 1.82218, 1.86705, 1.91341, 1.89353, 1.95141]]
linear_sgd_var_2 = [[0.720303, 0.271792, 0.203311, 0.140041, 0.11899, 0.0923637, 0.0836482, 0.0716346, 0.0515047, 0.0569852  ]]


ridge_ch_mse_1 = [[1.7383397085648389, 1.6449296528026238,1.627306827092249,1.6221962433251889,1.5220257888217517,1.4629208262048157, 
                  1.369495711183664, 1.331950971401656, 1.2493662931281593, 1.07250401751639]]
ridge_ch_var_1 = [[0.01064593192310081,0.013505361128773501,0.01799586357405375,0.021506437888529052,0.025609290991976015,0.03890843604008599,
                   0.04641956875061332,0.07122387156876844, 0.099714807713055, 0.21392460288779144 ]]

ridge_ch_mse_2 = [[1.9069360256951362,1.8651157893703398,1.7276273869737901,1.7418918660056495,1.7044038992763342,1.576378054800707,
                   1.575051733613962,1.3651657052408053, 1.3920851954908469,0.777157972102642]]
ridge_ch_var_2 = [[0.020327234134154697,0.024266764579071187,0.0301553731954174,0.039043500216507425,0.05283063359248569,
                  0.0741898081276679,0.09699562792933307,0.12359117529349316, 0.18310368740055516, 0.41701867567827494]]

ridge_sgd_mse_1 = [[1.11965, 1.38713, 1.49036, 1.6999, 1.72309, 1.84294, 1.88714, 1.91326, 1.89357,  1.95888]]
ridge_sgd_var_1 = [[0.259846, 0.14091, 0.109976,  0.0639465, 0.0549801,0.0414799, 0.0414118, 0.0299478, 0.0269002, 0.0214871]]

ridge_sgd_mse_2 = [[1.12395, 1.6014, 1.8293, 2.01492, 1.9243, 2.12254, 2.07292, 2.22684, 2.37904, 2.50058]]
ridge_sgd_var_2 = [[0.706654, 0.269621, 0.204099, 0.142054, 0.119736, 0.0924931, 0.0840442, 0.0720095, 0.0517215, 0.0570093]]

lasso_cd_mse_1 = [[1.01806, 1.26867, 1.32321, 1.36452, 1.45112, 1.51482, 1.56375, 1.60441, 1.69102, 1.77812]]
lasso_cd_var_1 = [[0.210075, 0.0971628, 0.070443, 0.0438106, 0.0373578, 0.0248336, 0.0223024, 0.0185596, 0.014584, 0.0118775]]

lasso_cd_mse_2 = [[0.859315, 1.35593, 1.32586, 1.53075, 1.58564, 1.71778, 1.7782, 1.75462, 1.90444, 1.92423, ]]
lasso_cd_var_2 = [[0.437213, 0.22048, 0.138607, 0.106169, 0.0773395, 0.0576591, 0.0456309, 0.0341759, 0.0253762, 0.0211679]]

lasso_sgd_mse_1 = [[1.12912, 1.38925, 1.48773, 1.71546, 1.7084, 1.82494, 1.89275, 1.91065, 1.89382, 1.94574]]
lasso_sgd_var_1 = [[0.2578, 0.135829, 0.1007, 0.0575809, 0.0567073, 0.0395526, 0.0377791, 0.0323927, 0.027794, 0.0226583]]

lasso_sgd_mse_2 = [[1.0114, 1.71569, 1.72813, 1.95964, 1.97598, 2.01935, 2.0731, 2.13639, 2.3496, 2.44309]]
lasso_sgd_var_2 = [[0.719171, 0.279334, 0.211023, 0.153373, 0.126581, 0.118961, 0.082853, 0.0778166, 0.0534741, 0.0634685]]

elastic_cd_mse_1 = [[1.09999, 1.25614, 1.29062, 1.37382, 1.44656, 1.49543, 1.57961, 1.60722, 1.62679, 1.69485   ]]
elastic_cd_var_1 = [[0.208939, 0.10433, 0.074132, 0.0431725, 0.0387068, 0.0292176, 0.0258284, 0.0187915, 0.0157468, 0.011962200000]]

elastic_cd_mse_2 = [[0.932861, 1.34455, 1.30388, 1.57398, 1.65405, 1.69449, 1.77856, 1.76592, 1.90624, 1.87363]]
elastic_cd_var_2 = [[0.457426, 0.217365, 0.135523, 0.109987, 0.0832292, 0.0627126, 0.0488553, 0.0356554, 0.0280172, 0.0236136]]

elastic_sgd_mse_1 = [[1.12847, 1.39041, 1.48664, 1.68603, 1.70683, 1.82592, 1.86409, 1.91113, 1.89368, 1.94639]]
elastic_sgd_var_1 = [[0.258393, 0.136095, 0.100958, 0.058459, 0.0562767, 0.0389571, 0.0366263, 0.0320338, 0.0283401, 0.0227106]]

elastic_sgd_mse_2 = [[1.01427, 1.71794, 1.72336, 1.98835, 1.90421, 2.01939, 2.07391, 2.13733, 2.35091, 2.44488]]
elastic_sgd_var_2 = [[0.73069, 0.288131, 0.207198, 0.144649, 0.123279, 0.116764, 0.0812873, 0.0769967, 0.0542021, 0.0622412]]

PLS_mse_1 = [[1.10662, 1.31144, 1.42002, 1.39654, 1.53091, 1.58472, 1.72896, 1.72404, 1.81376, 1.82908]]
PLS_var_1 = [[0.207117, 0.100209, 0.0717815, 0.0488025, 0.0360762, 0.0232973, 0.0183923, 0.0162824, 0.012023, 0.0106475]]

PLS_mse_2 = [[0.879737, 1.38535, 1.34171, 1.54323, 1.60888, 1.75628, 1.75197, 1.78723, 1.89565, 2.04405]]
PLS_var_2 = [[0.395335, 0.165881, 0.119094, 0.0947571, 0.0699232, 0.0493024, 0.0350191, 0.0258847, 0.0203541, 0.0164355]]




k = 0
colors = ["blue","orange","green","red","purple", "cyan", "black", "yellow", "pink"]
rip = np.arange(10)
data = [linear_svd_mse_1,linear_svd_var_1,linear_sgd_mse_1, linear_sgd_var_1,ridge_ch_mse_1,ridge_ch_var_1,ridge_sgd_mse_1,ridge_sgd_var_1,
       lasso_cd_mse_1,lasso_cd_var_1, lasso_sgd_mse_1, lasso_sgd_var_1, elastic_cd_mse_1, elastic_cd_var_1, 
        elastic_sgd_mse_1, elastic_sgd_var_1, PLS_mse_1, PLS_var_1]
labels = ["Linear SVD", "Linear SGD","Ridge Cholesky", "Ridge SGD","Lasso CD","Lasso SGD","Elastic CD", "Elastic SGD", "PLS"]
fig = plt.figure(figsize= (18,10))
while k < 9:
    cost = []
    conc = []
    conc = np.concatenate((normalize(data[k *2]), normalize(data[k *2 + 1])), axis = 0)
    for i in range(len(conc[0])):
        cost.append(0.5 * conc[0][i] + 0.5 * conc[1][i])
    plt.bar(rip+k*0.1, cost, label = labels[k], color = colors[k], width=0.1)
    k+=1

plt.xticks(rip+0.4, ["5%", "10%", "15%", "20%", "25%", "30%", "35%", "40%", "45%", "50%"])
plt.xlabel("Ripartition")
plt.ylabel("Cost")
plt.legend()
plt.grid(axis='y')
plt.title("Parameter 1")
plt.ylim(top=0.4) 
plt.show()



#Parameter 2


k = 0
colors = ["blue","orange","green","red","purple", "cyan", "black", "yellow", "pink"]
rip = np.arange(10)
data = [linear_svd_mse_2,linear_svd_var_2,linear_sgd_mse_2, linear_sgd_var_2,ridge_ch_mse_2,ridge_ch_var_2,ridge_sgd_mse_2,ridge_sgd_var_2,
       lasso_cd_mse_2,lasso_cd_var_2, lasso_sgd_mse_2, lasso_sgd_var_2, elastic_cd_mse_2, elastic_cd_var_2, 
        elastic_sgd_mse_2, elastic_sgd_var_2, PLS_mse_2, PLS_var_2]
labels = ["Linear SVD", "Linear SGD","Ridge Cholesky", "Ridge SGD","Lasso CD","Lasso SGD","Elastic CD", "Elastic SGD", "PLS"]
fig = plt.figure(figsize= (18,10))
while k < 9:
    cost = []
    conc = []
    conc = np.concatenate((normalize(data[k *2]), normalize(data[k *2 + 1])), axis = 0)
    for i in range(len(conc[0])):
        cost.append(0.5 * conc[0][i] + 0.5 * conc[1][i])
    plt.bar(rip+k*0.1, cost, label = labels[k], color = colors[k], width=0.1)
    k+=1

plt.xticks(rip+0.4, ["5%", "10%", "15%", "20%", "25%", "30%", "35%", "40%", "45%", "50%"])
plt.xlabel("Ripartition")
plt.ylabel("Cost")
plt.legend()
plt.grid(axis='y')
plt.title("Parameter 2")
plt.ylim(top=0.4) 
plt.show()

# %% [markdown]
# Comparison with NRMSEPiqr

# %%
import numpy as np
import matplotlib.pyplot as plt


ridge_ch_mse = [0.263784,0.285703,0.319196]
ridge_ch_var = [0.000348788, 8.6394e-5,0.000113223]

ridge_sgd_mse = [0.539804,0.570296,0.638238]
ridge_sgd_var = [0.00153639,0.00116472,0.00177075]

lasso_cd_mse = [0.331005,0.358126,0.380237]
lasso_cd_var = [0.00417895,0.00303226,0.00310308]

lasso_sgd_mse = [0.507297,0.573839,0.638994]
lasso_sgd_var = [0.0016337,0.000900942,0.00164421]

elastic_cd_mse = [0.307083,0.352643,0.348787]
elastic_cd_var = [0.00548131,0.00343464,0.00356991]

elastic_sgd_mse = [0.507764,0.573487,0.639392]
elastic_sgd_var = [0.00182158,0.000917566,0.00165184]

PLS_mse = [0.602303,0.653458,0.711946]
PLS_var = [0.00212982,0.000669567,0.000341277]

SVR_mse = [0.680712,0.695658,0.748583]
SVR_var = [0.680712,0.695658,0.748583]



k = 0
colors = ["blue","orange","green","red","purple", "cyan", "black", "yellow"]
rip = np.arange(3)
data = [ridge_ch_mse,ridge_ch_var,ridge_sgd_mse,ridge_sgd_var,
       lasso_cd_mse,lasso_cd_var, lasso_sgd_mse, lasso_sgd_var, elastic_cd_mse, elastic_cd_var, 
        elastic_sgd_mse, elastic_sgd_var, PLS_mse, PLS_var, SVR_mse, SVR_var]
labels = ["Ridge Cholesky", "Ridge SGD","Lasso CD","Lasso SGD","Elastic CD", "Elastic SGD", "PLS","SVR"]
fig = plt.figure(figsize= (18,10))
while k < 8:
    cost = []
    conc = {"NRMSEPiqr":[],"Var":[]}
    conc["NRMSEPiqr"] = data[k *2]
    conc["Var"] = data[k *2 + 1]
    print(conc)
    for i in range(3):
        cost.append(0.5 * conc["NRMSEPiqr"][i] + 0.5 * conc["Var"][i])
    plt.bar(rip+k*0.1, cost, label = labels[k], color = colors[k], width=0.1)
    print(cost)
    k+=1

plt.xticks(rip+0.4, ["25%", "50%","75%"])
plt.xlabel("Ripartition")
plt.ylabel("Cost")
plt.legend()
plt.grid(axis='y')
plt.title("Nitrogen")
plt.ylim(top=0.4) 
plt.show()
# Out:
# {'NRMSEPiqr': [0.263784, 0.285703, 0.319196], 'Var': [0.000348788, 8.6394e-05, 0.000113223]}
# [0.132066394, 0.142894697, 0.1596546115]
# {'NRMSEPiqr': [0.539804, 0.570296, 0.638238], 'Var': [0.00153639, 0.00116472, 0.00177075]}
# [0.270670195, 0.28573036, 0.320004375]
# {'NRMSEPiqr': [0.331005, 0.358126, 0.380237], 'Var': [0.00417895, 0.00303226, 0.00310308]}
# [0.167591975, 0.18057913, 0.19167003999999999]
# {'NRMSEPiqr': [0.507297, 0.573839, 0.638994], 'Var': [0.0016337, 0.000900942, 0.00164421]}
# [0.25446535, 0.287369971, 0.320319105]
# {'NRMSEPiqr': [0.307083, 0.352643, 0.348787], 'Var': [0.00548131, 0.00343464, 0.00356991]}
# [0.156282155, 0.17803882, 0.176178455]
# {'NRMSEPiqr': [0.507764, 0.573487, 0.639392], 'Var': [0.00182158, 0.000917566, 0.00165184]}
# [0.25479279, 0.287202283, 0.32052191999999996]
# {'NRMSEPiqr': [0.602303, 0.653458, 0.711946], 'Var': [0.00212982, 0.000669567, 0.000341277]}
# [0.30221641, 0.3270637835, 0.35614363849999997]
# ...
