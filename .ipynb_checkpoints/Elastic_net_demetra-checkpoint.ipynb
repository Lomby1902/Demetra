# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, PredictionErrorDisplay
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from tabulate import tabulate
import mlflow
from sklearn.linear_model import ElasticNet
import warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn_genetic import GASearchCV
from sklearn_genetic.space import Categorical, Integer, Continuous

path = 'SAMPLE_DATA_SET.xlsx'

# Read and load dataset
df= pd.read_excel(path, sheet_name=[0, 1])

# %% [markdown]
# INPUT DATA

# %%
X =df.get(0)
X = (X.iloc[:,1:]).values
X = X.T
print(X.shape)
# Out:
# (839, 444)

# %% [markdown]
# OUTPUT DATA

# %%
Y =df.get(1)
Y = (Y.iloc[:,:]).values
print(Y.shape)
# Out:
# (839, 2)

# %% [markdown]
# **ELASTIC NET with coordinate descent**

# %%
mlflow.set_experiment("Elastic Net CD")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")
import sys, os

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" 

#number of trials
trials = 100
np.random.seed(42)
seeds = np.random.randint(trials, size=trials)

ripartisions = [i/100 for i in range(5,55,5)]
results = []  

# create 5x2 subfigs
fig = plt.figure(constrained_layout=True, figsize=(20, 25))
fig.suptitle('Elastic Net regression test' + "\n")
subfigs = fig.subfigures(nrows=5, ncols=2).flatten()
k = 0

for ripartition in ripartisions:

    '''PARAM 1'''

    MSE_param1 = []

    best_MSE_1 = 100000000
    best_data_1 = {"Y_test": None, "Y_pred": None, "seed": None,"alpha":None,"r":None}

    run_name = str(ripartition) + " ripartition"
    print(run_name)
    with mlflow.start_run(run_name=run_name):
        mlflow.log_param('ripartition', ripartition)
    
        i = 0
        for i in range(trials):
            #Ripartition in training and test and
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y[:,0], test_size=ripartition, random_state=seeds[i])
            param_grid = {'alpha': Continuous(1/100000,0.01),"l1_ratio":Continuous(0,1)}
            elastic_reg_cd = ElasticNet(max_iter=5000, tol=1e-2)
    
            evolved_estimator = GASearchCV(estimator=elastic_reg_cd,
                              cv=5,
                              scoring='neg_mean_squared_error',
                              param_grid=param_grid,
                              n_jobs=-1,
                              verbose=False,
                              population_size=10,
                              generations=10)
    
            evolved_estimator.fit(X_train, Y_train)
    
            # Make predictions using the testing set
            Y_pred_elastic_cd =  evolved_estimator.predict(X_test)
    
            #save MSE of the first parameters
            MSE_param1.append(mean_squared_error(Y_test, Y_pred_elastic_cd))
    
            #check if this is the best model in terms of MSE
            if MSE_param1[-1] < best_MSE_1:
              best_MSE_1 = MSE_param1[-1]
              best_data_1["Y_test"] = Y_test
              best_data_1["Y_pred"] = Y_pred_elastic_cd
              best_data_1["alpha"] = float(evolved_estimator.best_params_["alpha"])
              best_data_1["r"] = float(evolved_estimator.best_params_["l1_ratio"])
              best_data_1["seed"] = seeds[i]

        mlflow.log_metric("Best_MSE1", best_MSE_1)
        mlflow.log_metric("Mean_MSE1", np.mean(MSE_param1))
        mlflow.log_metric("Var_MSE1", np.var(MSE_param1))
        mlflow.log_metric("alpha1", best_data_1["alpha"])
        mlflow.log_metric("r1", best_data_1["r"])
    
    
        '''PARAM 2'''
        MSE_param2 = []
    
        best_MSE_2 = 100000000
        best_data_2 = {"Y_test": None, "Y_pred": None, "seed": None,"alpha":None,"r":None}
    
        i = 0
        for i in range(trials):
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y[:,1], test_size=ripartition, random_state=seeds[i])
            param_grid = {'alpha': Continuous(1/100000,0.01),"l1_ratio":Continuous(0,1)}
            elastic_reg_cd = ElasticNet(max_iter=5000, tol=1e-2)
                
            evolved_estimator = GASearchCV(estimator=elastic_reg_cd,
                              cv=5,
                              scoring='neg_mean_squared_error',
                              param_grid=param_grid,
                              n_jobs=-1,
                              verbose=False,
                              population_size=10,
                              generations=10)
    
            # Train the model using the training sets
            evolved_estimator.fit(X_train, Y_train)
    
            # Make predictions using the testing set
            Y_pred_elastic_cd = evolved_estimator.predict(X_test)
    
            #save MSE of the second parameters
            MSE_param2.append(mean_squared_error(Y_test, Y_pred_elastic_cd))
    
            #check if this is the best model in terms of MSE
            if MSE_param2[-1] < best_MSE_2:
              best_MSE_2 = MSE_param2[-1]
              best_data_2["Y_test"] = Y_test
              best_data_2["Y_pred"] = Y_pred_elastic_cd
              best_data_2["alpha"] = float(evolved_estimator.best_params_["alpha"])
              best_data_2["r"] = float(evolved_estimator.best_params_["l1_ratio"])
              best_data_2["seed"] = seeds[i]


        mlflow.log_metric("Best_MSE2", best_MSE_2)
        mlflow.log_metric("Mean_MSE2", np.mean(MSE_param2))
        mlflow.log_metric("Var_MSE2", np.var(MSE_param2))
        mlflow.log_metric("alpha2", best_data_2["alpha"])
        mlflow.log_metric("r2", best_data_2["r"])

    results.append([str(ripartition * 100), str(best_MSE_1), str(best_MSE_2),
                    (np.mean(MSE_param1)), str(np.mean(MSE_param2)), str(np.var(MSE_param1)), str(np.var(MSE_param2)),
                    str(best_data_1["alpha"]), str(best_data_2["alpha"]), best_data_1["seed"],best_data_2["seed"], 
                    best_data_1["r"], best_data_2["r"]])

    '''PLOT THE BEST MODELS'''
    subfigs[k].suptitle(
        "Elastic Net with Coordinate Descent" + "\n" + "Best MSE results" + "\n" + f"Test size(%): {ripartition * 100}")
    # create 1x2 subplots per subfig
    axs = subfigs[k].subplots(nrows=1, ncols=2)
    axs[0].scatter(best_data_1["Y_test"], best_data_1["Y_pred"], c='blue', label='Actual vs Predicted')
    axs[0].plot([min(best_data_1["Y_test"]), max(best_data_1["Y_test"])],
                [min(best_data_1["Y_test"]), max(best_data_1["Y_test"])], '--', c='red', label='Perfect Prediction')
    axs[0].legend()
    axs[0].set_xlabel("Actual values")
    axs[0].set_ylabel("Predicted value")
    axs[0].set_title(
        "Parameter 1" + "\n" + "MSE: " + str(min(MSE_param1)) + "\n" + " alpha= " + str(best_data_1["alpha"]) + ", r= " + str(best_data_1["r"]))

    axs[1].scatter(best_data_2["Y_test"], best_data_2["Y_pred"], c='blue', label='Actual vs Predicted')
    axs[1].plot([min(best_data_2["Y_test"]), max(best_data_2["Y_test"])],
                [min(best_data_2["Y_test"]), max(best_data_2["Y_test"])], '--', c='red', label='Perfect Prediction')
    axs[1].legend()
    axs[1].set_xlabel("Actual values")
    axs[1].set_ylabel("Predicted value")
    axs[1].set_title(
        "Parameter 2" + "\n" + "MSE: " + str(min(MSE_param2)) + "\n" + " alpha= " + str(best_data_2["alpha"])  + ", r= " + str(best_data_2["r"]))
    k += 1


'''SHOW RESULTS'''
headers = ["Test size(%)", "Best(MSE1)", "Best(MSE2)", "Mean(MSE1)", "Mean(MSE2)", "Var(MSE1)", "Var(MSE2)",
           "alpha1","alpha2","Seed1","Seed2","r1","r2"]

print(tabulate(results, headers,  tablefmt="double_outline"))
# Out:
# Exception ignored in: Fatal Python error: init_import_site: Failed to import the site module
# Python runtime state: initialized
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/site.py", line 636, in <module>
# <function _releaseLock at 0x77334970dab0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#         main()
#   File "/usr/lib/python3.10/site.py", line 622, in main
#     known_paths = addusersitepackages(known_paths)
#   File "/usr/lib/python3.10/site.py", line 349, in addusersitepackages
#     addsitedir(user_site, known_paths)
#   File "/usr/lib/python3.10/site.py", line 227, in addsitedir
#     names = os.listdir(sitedir)
# KeyboardInterrupt
# def _releaseLock():
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#   File "/usr/lib/python3.10/subprocess.py", line 69, in <module>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
# Traceback (most recent call last):
#     import msvcrt
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
# ModuleNotFoundError: No module named 'msvcrt'
#     __import__(pkg_name)
#
# During handling of the above exception, another exception occurred:
#
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 129, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .parallel import Parallel
#     from .backports import concurrency_safe_rename
#     from .backports import concurrency_safe_rename
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     import numpy as np
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 158, in <module>
#     import numpy as np
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 149, in <module>
#     from .memory import Memory
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 12, in <module>
#     from . import lib
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/lib/__init__.py", line 23, in <module>
#     from . import ctypeslib
#   File "<frozen importlib._bootstrap>", line 1024, in _find_and_load
#     __import__(pkg_name)
#     import asyncio
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#   File "/usr/lib/python3.10/asyncio/__init__.py", line 8, in <module>
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#     from . import index_tricks
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/lib/index_tricks.py", line 12, in <module>
#   File "<frozen importlib._bootstrap>", line 170, in __enter__
#     from .base_events import *
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 25, in <module>
#     import numpy.matrixlib as matrixlib
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/matrixlib/__init__.py", line 4, in <module>
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap>", line 196, in _get_module_lock
#     from . import defmatrix
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/matrixlib/defmatrix.py", line 12, in <module>
#   File "<frozen importlib._bootstrap>", line 73, in __init__
#     import subprocess
#   File "/usr/lib/python3.10/subprocess.py", line 74, in <module>
#     from numpy.linalg import matrix_power
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/linalg/__init__.py", line 73, in <module>
#     from .memory import Memory
#   File "<frozen importlib._bootstrap_external>", line 969, in get_code
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
# KeyboardInterrupt
#     from . import linalg
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/linalg/linalg.py", line 37, in <module>
#     import _posixsubprocess
#   File "<frozen importlib._bootstrap_external>", line 1091, in path_stats
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     from ._store_backends import CacheWarning  # noqa
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from numpy._typing import NDArray
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/_typing/__init__.py", line 107, in <module>
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
#     from ._char_codes import (
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/_typing/_char_codes.py", line 39, in <module>
#     from .backports import concurrency_safe_rename
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#     _LongDoubleCodes = Literal["longdouble", "longfloat", "g", "=g", "<g", ">g"]
#   File "/usr/lib/python3.10/typing.py", line 410, in __getitem__
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     import numpy as np
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 149, in <module>
#   File "<frozen importlib._bootstrap>", line 746, in find_spec
#     return self._getitem(self, *parameters)
#   File "/usr/lib/python3.10/typing.py", line 309, in inner
# KeyboardInterrupt
#     return cached(*args, **kwds)
#   File "/usr/lib/python3.10/typing.py", line 564, in Literal
#     from . import lib
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/lib/__init__.py", line 18, in <module>
#     from . import scimath as emath
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/lib/scimath.py", line 37, in <module>
#     return _LiteralGenericAlias(self, parameters)
#   File "/usr/lib/python3.10/typing.py", line 1019, in __init__
#     from numpy.lib.type_check import isreal
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/lib/type_check.py", line 683, in <module>
#     super().__init__(origin, inst=inst, name=name)
#   File "/usr/lib/python3.10/typing.py", line 951, in __init__
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     def common_type(*arrays):
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/overrides.py", line 145, in decorator
#     self.__slots__ = None  # This is not documented.
#   File "/usr/lib/python3.10/typing.py", line 989, in __setattr__
#     verify_matching_signatures(implementation, dispatcher)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/overrides.py", line 85, in verify_matching_signatures
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     implementation_spec = ArgSpec(*getargspec(implementation))
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/_utils/_inspect.py", line 110, in getargspec
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     super().__setattr__(attr, val)
# KeyboardInterrupt
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 12, in <module>
#     import asyncio
#   File "/usr/lib/python3.10/asyncio/__init__.py", line 8, in <module>
#     from .base_events import *
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 39, in <module>
#     from . import coroutines
#   File "/usr/lib/python3.10/asyncio/coroutines.py", line 5, in <module>
#     import inspect
#   File "/usr/lib/python3.10/inspect.py", line 37, in <module>
#     import ast
#   File "/usr/lib/python3.10/ast.py", line 28, in <module>
#     from _ast import *
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
#     from .backports import concurrency_safe_rename
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#     import numpy as np
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 130, in <module>
#     from numpy.__config__ import show as show_config
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__config__.py", line 4, in <module>
#     from numpy.core._multiarray_umath import (
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/__init__.py", line 24, in <module>
#     from . import multiarray
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/multiarray.py", line 10, in <module>
#     from . import overrides
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/overrides.py", line 8, in <module>
#     from numpy.core._multiarray_umath import (
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
#     args, varargs, varkw = getargs(func.__code__)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/_utils/_inspect.py", line 84, in getargs
#     for i in range(nargs):
# KeyboardInterrupt
# Exception ignored in: Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# <function _releaseLock at 0x77334970dab0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/usr/lib/python3.10/re.py", line 293, in _compile
# Traceback (most recent call last):
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#     __import__(pkg_name)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 13, in <module>
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 28, in <module>
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     import datetime
#   File "/usr/lib/python3.10/datetime.py", line 2185, in <module>
#     from . import hashing
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/hashing.py", line 16, in <module>
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 12, in <module>
#     __import__(pkg_name)
#     import asyncio
#   File "/usr/lib/python3.10/asyncio/__init__.py", line 8, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     import decimal
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     from .base_events import *
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 18, in <module>
#     return _cache[type(pattern), pattern, flags]
#     import concurrent.futures
#     from .memory import Memory
#   File "/usr/lib/python3.10/concurrent/futures/__init__.py", line 8, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     from ._store_backends import CacheWarning  # noqa
# KeyError: (<class 'str'>, '^(?:\\s*(\\w+)\\s*\\.)?\\s*(\\w+)', 0)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
# Traceback (most recent call last):
#     from concurrent.futures._base import (F    def _releaseLock():IRST_COMPLETED,
#   File "/usr/lib/python3.10/concurrent/futures/_base.py", line 7, in <module>
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     from .backports import concurrency_safe_rename
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#     import logging
#   File "/usr/lib/python3.10/logging/__init__.py", line 28, in <module>
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#     import numpy as np
#     __import__(pkg_name)
#     from string import Template
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 156, in <module>
#   File "/usr/lib/python3.10/string.py", line 146, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     Template.__init_subclass__()
#   File "/usr/lib/python3.10/string.py", line 85, in __init_subclass__
#   File "<frozen importlib._bootstrap_external>", line 1411, in _get_spec
#     from . import polynomial
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/polynomial/__init__.py", line 116, in <module>
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     cls.pattern = _re.compile(pattern, cls.flags | _re.VERBOSE)
#   File "<frozen importlib._bootstrap_external>", line 1576, in find_spec
#   File "/usr/lib/python3.10/re.py", line 251, in compile
#     from ._store_backends import CacheWarning  # noqa
#     __import__(pkg_name)
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 17, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/__init__.py", line 114, in <module>
#     from .backports import concurrency_safe_rename
# KeyboardInterrupt
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/backports.py", line 112, in <module>
#     import numpy as np
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__init__.py", line 130, in <module>
#     from .polynomial import Polynomial
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#     return _compile(pattern, flags)
#   File "/usr/lib/python3.10/re.py", line 303, in _compile
#     from .memory import Memory
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/memory.py", line 29, in <module>
#     from numpy.__config__ import show as show_config
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/__config__.py", line 4, in <module>
#     from ._store_backends import CacheWarning  # noqa
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/_store_backends.py", line 19, in <module>
#     from numpy.core._multiarray_umath import (
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/__init__.py", line 24, in <module>
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#     from .logger import format_time
#     from . import multiarray
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/multiarray.py", line 10, in <module>
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/logger.py", line 18, in <module>
#     p = sre_compile.compile(pattern, flags)
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "/usr/lib/python3.10/sre_compile.py", line 788, in compile
#     from . import overrides
#   File "/home/giovanni/.local/lib/python3.10/site-packages/numpy/core/overrides.py", line 8,
# KeyboardInterrupt:
# in <module>
#     import pprint
#   File "/usr/lib/python3.10/pprint.py", line 38, in <module>
#     from numpy.core._multiarray_umath import (
#   File "<frozen importlib._bootstrap>", line 1022, in _find_and_load
#     import dataclasses as _dataclasses
#   File "/usr/lib/python3.10/dataclasses.py", line 223, in <module>
# KeyboardInterrupt
#     p = sre_parse.parse(p, flags)
#   File "/usr/lib/python3.10/sre_parse.py", line 955, in parse
#     _MODULE_IDENTIFIER_RE = re.compile(r'^(?:\s*(\w+)\s*\.)?\s*(\w+)')
#   File "/usr/lib/python3.10/re.py", line 251, in compile
#     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#   File "/usr/lib/python3.10/sre_parse.py", line 444, in _parse_sub
#     return _compile(pattern, flags)
#   File "/usr/lib/python3.10/re.py", line 293, in _compile
#     itemsappend(_parse(source, state, verbose, nested + 1,
#   File "/usr/lib/python3.10/sre_parse.py", line 841, in _parse
#     class timezone(tzinfo):
#     p = _parse_sub(source, state, sub_verbose, nested + 1)
#   File "/usr/lib/python3.10/datetime.py", line 2278, in timezone
#   File "/usr/lib/python3.10/sre_parse.py", line 444, in _parse_sub
#   File "<frozen importlib._bootstrap_external>", line 1012, in get_code
#     return _cache[type(pattern), pattern, flags]
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap_external>", line 672, in _compile_bytecode
#     itemsappend(_parse(source, state, verbose, nested + 1,
#   File "/usr/lib/python3.10/sre_parse.py", line 836, in _parse
# KeyboardInterrupt
#     group = state.opengroup(name)
#   File "/usr/lib/python3.10/sre_parse.py", line 87, in opengroup
#     self.groupwidths.append(None)
# KeyboardInterrupt
#     _maxoffset = timedelta(hours=24, microseconds=-1)
#   File "/usr/lib/python3.10/datetime.py", line 536, in __new__
#     microseconds = round(microseconds + usdouble)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/giovanni/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 108, in get
#     if not self._rlock.acquire(block, timeout):
# KeyboardInterrupt
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# /tmp/ipykernel_198731/2772755198.py in <module>
#      50                               generations=10)
#      51
# ---> 52             evolved_estimator.fit(X_train, Y_train)
#      53
#      54             # Make predictions using the testing set
#
# ~/.local/lib/python3.10/site-packages/sklearn_genetic/genetic_search.py in fit(self, X, y, callbacks)
#     490
#     491         # Optimization routine from the selected evolutionary algorithm
# --> 492         pop, log, n_gen = self._select_algorithm(pop=self._pop, stats=self._stats, hof=self._hof)
#     493
#     494         # Update the _n_iterations value as the algorithm could stop earlier due a callback
#
# ~/.local/lib/python3.10/site-packages/sklearn_genetic/genetic_search.py in _select_algorithm(self, pop, stats, hof)
#     570         selected_algorithm = algorithms_factory.get(self.algorithm, None)
#     571         if selected_algorithm:
# --> 572             pop, log, gen = selected_algorithm(
#     573                 pop,
#     574                 self.toolbox,
#
# ~/.local/lib/python3.10/site-packages/sklearn_genetic/algorithms.py in eaMuPlusLambda(population, toolbox, mu, lambda_, cxpb, mutpb, ngen, stats, halloffame, callbacks, verbose, estimator, **kwargs)
#     325             invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#     326             fitnesses = toolbox.map(toolbox.evaluate, invalid_ind)
# --> 327             for ind, fit in zip(invalid_ind, fitnesses):
#     328                 ind.fitness.values = fit
#     329
#
# ~/.local/lib/python3.10/site-packages/sklearn_genetic/genetic_search.py in evaluate(self, individual)
#     397
#     398         # Compute the cv-metrics
# --> 399         cv_results = cross_validate(
#     400             local_estimator,
#     401             self.X_,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     428     # independent, and that it is pickle-able.
#     429     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430     results = parallel(
#     431         delayed(_fit_and_score)(
#     432             clone(estimator),
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      65             for delayed_func, args, kwargs in iterable
#      66         )
# ---> 67         return super().__call__(iterable_with_config)
#      68
#      69
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in _retrieve(self)
#    1752             # worker traceback.
#    1753             if self._aborting:
# -> 1754                 self._raise_error_fast()
#    1755                 break
#    1756
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in _raise_error_fast(self)
#    1787         # called directly or if the generator is gc'ed.
#    1788         if error_job is not None:
# -> 1789             error_job.get_result(self.timeout)
#    1790
#    1791     def _warn_exit_early(self):
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in get_result(self, timeout)
#     743             # callback thread, and is stored internally. It's just waiting to
#     744             # be returned.
# --> 745             return self._return_or_raise()
#     746
#     747         # For other backends, the main thread needs to run the retrieval step.
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in _return_or_raise(self)
#     761         try:
#     762             if self.status == TASK_ERROR:
# --> 763                 raise self._result
#     764             return self._result
#     765         finally:
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %% [markdown]
# **ELASTIC NET with SGD**

# %%
mlflow.set_experiment("Elastic Net SGD")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")
from sklearn.linear_model import SGDRegressor
import sys, os

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" 

#number of trials
trials = 100
np.random.seed(42)
seeds = np.random.randint(trials, size=trials)

ripartisions = [i/100 for i in range(5,55,5)]
results = [] 

# create 5x2 subfigs
fig = plt.figure(constrained_layout=True, figsize=(20, 25))
fig.suptitle('Elastic Net regression test' + "\n")
subfigs = fig.subfigures(nrows=5, ncols=2).flatten()
k = 0

for ripartition in ripartisions:

    '''PARAM 1'''

    MSE_param1 = []

    best_MSE_1 = 100000000
    best_data_1 = {"Y_test":None, "Y_pred":None}

    run_name = str(ripartition) + " ripartition"
    with mlflow.start_run(run_name=run_name):
        mlflow.log_param('ripartition', ripartition)

        i = 0
        for i in range(trials):
            #Ripartition in training and test and
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y[:,0], test_size=ripartition, random_state=seeds[i])
            param_grid = {'alpha': Continuous(1/100000,0.01),"l1_ratio":Continuous(0,1)}
            elastic_reg_sgd = SGDRegressor(max_iter=5000, tol=1e-5, penalty="elasticnet", eta0=0.01,
                                                n_iter_no_change=10, random_state=42)

            evolved_estimator = GASearchCV(estimator=elastic_reg_sgd,
                              cv=5,
                              scoring='neg_mean_squared_error',
                              param_grid=param_grid,
                              n_jobs=-1,
                              verbose=False,
                              population_size=10,
                              generations=10)
    
            # Train the model using the training sets
            evolved_estimator.fit(X_train, Y_train)
    
            # Make predictions using the testing set
            Y_pred_elastic_sgd =  evolved_estimator.predict(X_test)
    
            #save MSE of the first parameters
            MSE_param1.append(mean_squared_error(Y_test,  Y_pred_elastic_sgd))
    
            #check if this is the best model in terms of MSE
            if MSE_param1[-1] < best_MSE_1:
              best_MSE_1 = MSE_param1[-1]
              best_data_1["Y_test"] = Y_test
              best_data_1["Y_pred"] = Y_pred_elastic_cd
              best_data_1["alpha"] = float(evolved_estimator.best_params_["alpha"])
              best_data_1["r"] = float(evolved_estimator.best_params_["l1_ratio"])
              best_data_1["seed"] = seeds[i]

        mlflow.log_metric("Best_MSE1", best_MSE_1)
        mlflow.log_metric("Mean_MSE1", np.mean(MSE_param1))
        mlflow.log_metric("Var_MSE1", np.var(MSE_param1))
        mlflow.log_metric("alpha1", best_data_1["alpha"])
        mlflow.log_metric("r1", best_data_1["r"])
    
    
        '''PARAM 2'''
        MSE_param2 = []
    
        best_MSE_2 = 100000000
        best_data_2 = {"Y_test":None, "Y_pred":None}
    
        i = 0
        for i in range(trials):
            X_train, X_test, Y_train, Y_test = train_test_split(X, Y[:,1], test_size=ripartition, random_state=seeds[i])
            param_grid = {'alpha': Continuous(1/100000,0.01),"l1_ratio":Continuous(0,1)}
            elastic_reg_sgd = SGDRegressor(max_iter=5000, tol=1e-5, penalty="elasticnet", eta0=0.01,
                                                n_iter_no_change=10, random_state=42)

            evolved_estimator = GASearchCV(estimator=elastic_reg_sgd,
                              cv=5,
                              scoring='neg_mean_squared_error',
                              param_grid=param_grid,
                              n_jobs=-1,
                              verbose=False,
                              population_size=10,
                              generations=10)
    
            # Train the model using the training sets
            evolved_estimator.fit(X_train, Y_train)
    
            # Make predictions using the testing set
            Y_pred_elastic_sgd =  evolved_estimator.predict(X_test)
    
            #save MSE of the second parameters
            MSE_param2.append(mean_squared_error(Y_test, Y_pred_elastic_sgd))
    
            #check if this is the best model in terms of MSE
            if MSE_param2[-1] < best_MSE_2:
              best_MSE_2 = MSE_param2[-1]
              best_data_2["Y_test"] = Y_test
              best_data_2["Y_pred"] = Y_pred_elastic_cd
              best_data_2["alpha"] = float(evolved_estimator.best_params_["alpha"])
              best_data_2["r"] = float(evolved_estimator.best_params_["l1_ratio"])
              best_data_2["seed"] = seeds[i]


        mlflow.log_metric("Best_MSE2", best_MSE_2)
        mlflow.log_metric("Mean_MSE2", np.mean(MSE_param2))
        mlflow.log_metric("Var_MSE2", np.var(MSE_param2))
        mlflow.log_metric("alpha2", best_data_2["alpha"])
        mlflow.log_metric("r2", best_data_2["r"])

    results.append([str(ripartition * 100), str(best_MSE_1), str(best_MSE_2),
                    (np.mean(MSE_param1)), str(np.mean(MSE_param2)), str(np.var(MSE_param1)), str(np.var(MSE_param2)),
                    str(best_data_1["alpha"]), str(best_data_2["alpha"]), best_data_1["seed"],best_data_2["seed"], 
                    best_data_1["r"], best_data_2["r"]])

    '''PLOT THE BEST MODELS'''
    subfigs[k].suptitle(
        "Elastic Net with SGD" + "\n" + "Best MSE results" + "\n" + f"Test size(%): {ripartition * 100}")
    # create 1x2 subplots per subfig
    axs = subfigs[k].subplots(nrows=1, ncols=2)
    axs[0].scatter(best_data_1["Y_test"], best_data_1["Y_pred"], c='blue', label='Actual vs Predicted')
    axs[0].plot([min(best_data_1["Y_test"]), max(best_data_1["Y_test"])],
                [min(best_data_1["Y_test"]), max(best_data_1["Y_test"])], '--', c='red', label='Perfect Prediction')
    axs[0].legend()
    axs[0].set_xlabel("Actual values")
    axs[0].set_ylabel("Predicted value")
    axs[0].set_title(
        "Parameter 1" + "\n" + "MSE: " + str(min(MSE_param1)) + "\n" + " alpha= " + str(best_data_1["alpha"]) + ", r= " + best_data_1["r"])

    axs[1].scatter(best_data_2["Y_test"], best_data_2["Y_pred"], c='blue', label='Actual vs Predicted')
    axs[1].plot([min(best_data_2["Y_test"]), max(best_data_2["Y_test"])],
                [min(best_data_2["Y_test"]), max(best_data_2["Y_test"])], '--', c='red', label='Perfect Prediction')
    axs[1].legend()
    axs[1].set_xlabel("Actual values")
    axs[1].set_ylabel("Predicted value")
    axs[1].set_title(
        "Parameter 2" + "\n" + "MSE: " + str(min(MSE_param2)) + "\n" + " alpha= " + str(best_data_2["alpha"])  + ", r= " + best_data_2["r"])
    k += 1


'''SHOW RESULTS'''
headers = ["Test size(%)", "Best(MSE1)", "Best(MSE2)", "Mean(MSE1)", "Mean(MSE2)", "Var(MSE1)", "Var(MSE2)",
           "alpha1","alpha2","Seed1","Seed2","r1","r2"]

print(tabulate(results, headers,  tablefmt="double_outline"))
